# %%
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv(r"D:\mtcars.csv")

plt.hist(df["mpg"], bins=5, edgecolor="black")
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of MPG")
plt.show()

# %%
plt.scatter(df["mpg"], df["mpg"])
plt.xlabel("weight (wt)")
plt.ylabel("MPG")
plt.title("weight vs MPG")
plt.show()

# %%
transmission = df["am"].value_counts()

plt.bar(transmission.index, transmission.values)
plt.xlabel("Transmission Type")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of Transmission Type")
plt.show()

# %%
plt.boxplot(df["mpg"])
plt.ylabel("MPG")
plt.title("Box and Whisker Plot of MPF")
plt.show()
print(df["mpg"].describe())
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64
